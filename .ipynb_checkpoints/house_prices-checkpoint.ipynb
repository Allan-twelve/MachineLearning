# %% [markdown]
# ## 房屋价格预测

# %% [markdown]
# ### 引入相关库

# %%
# 第三方库引入
import pandas as pd
import matplotlib.pyplot as plt
# 引入数据分析库
from DataSet_tools.data_processing import PreProcessing
from DataSet_tools.data_split import train_test_split, cross_validation
from DataSet_tools.score import rSquare, MAE, MSE, RMSE, MAPE
# 引入线性模型
from LinearRegression import NormalEquation, GradientDescent

# %matplotlib inline

# %% [markdown]
# ### 读取数据，设置绘图风格，引入数据预处理库

# %%
data = pd.read_csv('Data/house-prices-advanced-regression-techniques/train.csv')
plt.style.use('seaborn')
pp = PreProcessing()

# %% [markdown]
# ### 展示数据

# %%
data.head(10)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
# 5   6          50       RL         85.0    14115   Pave   NaN      IR1
# 6   7          20       RL         75.0    10084   Pave   NaN      Reg
# 7   8          60       RL          NaN    10382   Pave   NaN      IR1
# 8   9          50       RM         51.0     6120   Pave   NaN      Reg
# 9  10         190       RL         50.0     7420   Pave   NaN      Reg
#
#   LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# ...

# %% [markdown]
# ### 去除编号列，并查看各项数据

# %%
data = data.drop(['Id'], axis=1)
data.describe()
# Out:
#         MSSubClass  LotFrontage        LotArea  OverallQual  OverallCond  \
# count  1460.000000  1201.000000    1460.000000  1460.000000  1460.000000
# mean     56.897260    70.049958   10516.828082     6.099315     5.575342
# std      42.300571    24.284752    9981.264932     1.382997     1.112799
# min      20.000000    21.000000    1300.000000     1.000000     1.000000
# 25%      20.000000    59.000000    7553.500000     5.000000     5.000000
# 50%      50.000000    69.000000    9478.500000     6.000000     5.000000
# 75%      70.000000    80.000000   11601.500000     7.000000     6.000000
# max     190.000000   313.000000  215245.000000    10.000000     9.000000
#
#          YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1   BsmtFinSF2  ...  \
# count  1460.000000   1460.000000  1452.000000  1460.000000  1460.000000  ...
# mean   1971.267808   1984.865753   103.685262   443.639726    46.549315  ...
# std      30.202904     20.645407   181.066207   456.098091   161.319273  ...
# ...

# %% [markdown]
# ### 检查缺失值

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1460 non-null   int64
#  1   MSZoning       1460 non-null   object
#  2   LotFrontage    1201 non-null   float64
#  3   LotArea        1460 non-null   int64
#  4   Street         1460 non-null   object
#  5   Alley          91 non-null     object
#  6   LotShape       1460 non-null   object
#  7   LandContour    1460 non-null   object
#  8   Utilities      1460 non-null   object
#  9   LotConfig      1460 non-null   object
#  10  LandSlope      1460 non-null   object
#  11  Neighborhood   1460 non-null   object
#  12  Condition1     1460 non-null   object
#  13  Condition2     1460 non-null   object
#  14  BldgType       1460 non-null   object
#  15  HouseStyle     1460 non-null   object
#  16  OverallQual    1460 non-null   int64
# ...

# %% [markdown]
# ### 填补部分缺失值, 删去缺失值较多的列

# %%
data = pp.FillNan(data, method='fb', limit=10)
data = data.dropna(axis=1)

# %% [markdown]
# ### 再次检查缺失值

# %%
data.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# ### 查看数据

# %%
data.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0          60       RL         65.0     8450   Pave      Reg         Lvl
# 1          20       RL         80.0     9600   Pave      Reg         Lvl
# 2          60       RL         68.0    11250   Pave      IR1         Lvl
# 3          70       RL         60.0     9550   Pave      IR1         Lvl
# 4          60       RL         84.0    14260   Pave      IR1         Lvl
#
#   Utilities LotConfig LandSlope  ... EnclosedPorch 3SsnPorch ScreenPorch  \
# 0    AllPub    Inside       Gtl  ...             0         0           0
# 1    AllPub       FR2       Gtl  ...             0         0           0
# 2    AllPub    Inside       Gtl  ...             0         0           0
# 3    AllPub    Corner       Gtl  ...           272         0           0
# 4    AllPub       FR2       Gtl  ...             0         0           0
#
#   PoolArea MiscVal  MoSold  YrSold  SaleType  SaleCondition SalePrice
# ...

# %% [markdown]
# ## 将所有字符列进行标签编码(数据分析是不能处理object类型的)

# %% [markdown]
# ### 提取类型为object的列

# %%
obj = data.dtypes[(data.dtypes == object) == True].index

# %% [markdown]
# ### 标签编码

# %%
data[obj] = pp.LabelEncode(data[obj])

# %% [markdown]
# ### 查看数据

# %%
data.head()
# Out:
#    MSSubClass  MSZoning  LotFrontage  LotArea  Street  LotShape  LandContour  \
# 0          60         0         65.0     8450       0         0            2
# 1          20         0         80.0     9600       0         0            2
# 2          60         0         68.0    11250       0         1            2
# 3          70         0         60.0     9550       0         1            2
# 4          60         0         84.0    14260       0         1            2
#
#    Utilities  LotConfig  LandSlope  ...  EnclosedPorch  3SsnPorch  \
# 0          0          3          2  ...              0          0
# 1          0          4          2  ...              0          0
# 2          0          3          2  ...              0          0
# 3          0          0          2  ...            272          0
# 4          0          4          2  ...              0          0
#
#    ScreenPorch  PoolArea  MiscVal  MoSold  YrSold  SaleType  SaleCondition  \
# ...

# %% [markdown]
# ### 异常值处理

# %%
# 先取出原来是不是object类型的列, 因为经过标签编码的列没有异常值
copy = data.copy()
index = copy.drop(obj, axis=1).columns

# %% [markdown]
# ### 用箱线图查看异常值

# %%
fig = plt.figure(figsize=(15, 15))
for i in range(36):
    ax = fig.add_subplot(6, 6, i+1)
    ax.boxplot(data[index[i]], sym='rx', widths=0.6, showmeans=True)
    ax.set_title(index[i])
fig.tight_layout()

# %% [markdown]
# ### 由图可知部分特征存在异常值
# ### 删去异常值

# %%
data[index] = pp.Clean(data[index])

# %% [markdown]
# ### 用箱线图再次查看异常值

# %%
fig = plt.figure(figsize=(15, 15))
for i in range(36):
    ax = fig.add_subplot(6, 6, i+1)
    ax.boxplot(data[index[i]], sym='rx', widths=0.6, showmeans=True)
    ax.set_title(index[i])
fig.tight_layout()

# %% [markdown]
# ### 大部分异常值已清除完毕 （这里的清除异常值是根据箱线图的原理）
# #### 部分数据清理后只剩0， 说明这些原始数据0占大多数（可以认为它们对区分不同的数据贡献很小），
# #### 这里选择删去

# %%
data = data.drop(['BsmtFinSF2', 'LowQualFinSF', 'BsmtHalfBath',
                  'KitchenAbvGr', 'EnclosedPorch', '3SsnPorch',
                  'ScreenPorch', 'PoolArea', 'MiscVal', ], axis=1)

# %% [markdown]
# ### 特征选择

# %%
# 根据皮尔森指数，观察各特征值的相关性
dt_corr = data.dropna().corr()
corr = dt_corr['SalePrice']
corr
# Out:
# MSSubClass       0.112060
# MSZoning        -0.040689
# LotFrontage      0.235530
# LotArea          0.366501
# Street          -0.044036
#                    ...
# MoSold           0.068543
# YrSold          -0.027262
# SaleType        -0.206013
# SaleCondition   -0.092430
# SalePrice        1.000000
# Name: SalePrice, Length: 67, dtype: float64

# %% [markdown]
# ### 画出各个特征之间关系的热力图

# %%
fig = plt.figure(figsize=(8, 8))
ax = plt.axes()
map = ax.imshow(dt_corr, cmap='rainbow')
fig.colorbar(map)

# %% [markdown]
# ### 选取皮尔森系数大于0.1的特征

# %%
c = corr[abs(corr) > 0.1]
c
# Out:
# MSSubClass      0.112060
# LotFrontage     0.235530
# LotArea         0.366501
# LotShape        0.249434
# Neighborhood   -0.210863
# BldgType        0.132678
# OverallQual     0.697877
# OverallCond    -0.123127
# YearBuilt       0.556647
# YearRemodAdd    0.525288
# Exterior1st     0.210818
# Exterior2nd     0.177390
# MasVnrType     -0.322704
# MasVnrArea      0.292103
# ExterQual      -0.388207
# ExterCond      -0.156682
# Foundation      0.468479
# BsmtExposure   -0.205976
# BsmtFinType1   -0.168928
# BsmtFinSF1      0.279103
# BsmtUnfSF       0.183785
# TotalBsmtSF     0.519806
# Heating        -0.107398
# HeatingQC       0.333912
# CentralAir     -0.294271
# Electrical     -0.254088
# 1stFlrSF        0.492049
# 2ndFlrSF        0.300418
# GrLivArea       0.640551
# BsmtFullBath    0.193792
# FullBath        0.545586
# HalfBath        0.268561
# BedroomAbvGr    0.227507
# KitchenQual    -0.173922
# TotRmsAbvGrd    0.451722
# Functional      0.104078
# Fireplaces      0.437947
# ...

# %% [markdown]
# ## 观察每个特征值与房子价格的关系

# %%
# 绘出每个连续型特征关于价格的散点图
ind = list(set(c.index).difference(set(obj)))
ind.remove('SalePrice')
ind.append('SalePrice')
dt = data[ind].copy()
index = dt.columns
fig = plt.figure(figsize=(15, 15))
for i in range(dt.shape[1]-1):
    ax = fig.add_subplot(5, 5, i+1)
    if i % 2 == 0:
        ax.plot(dt.iloc[:, i], dt.iloc[:, -1], '.', color='orange')
    else:
        ax.plot(dt.iloc[:, i], dt.iloc[:, -1], '.', color='lime')
    ax.set_title(index[i])
fig.tight_layout()

# %%
# 绘出每个连续型特征关于价格的直方图
fig = plt.figure(figsize=(15, 15))
for i in range(dt.shape[1]-1):
    ax = fig.add_subplot(5, 5, i+1)
    if i % 2 == 0:
        ax.hist(dt.iloc[:, i], color='orange')
    else:
        ax.hist(dt.iloc[:, i], color='lime')
    ax.set_title(index[i])
fig.tight_layout()

# %% [markdown]
# #### 可见大部分特征都与SalePrice线性相关
# #### 而GarageArea、LotFrontage、GrLivArea、TotalBsmtSF、LotArea等特征都基本符合正态分布

# %% [markdown]
# ## 分割训练集和测试集

# %%
dt = data[c.index].copy()
x = dt.drop(['SalePrice'], axis=1)
y = dt[['SalePrice']]
# 此处分割函数为随机分割，每次运行，训练集和测试集都不一样
x_train, x_test, y_train, y_test = train_test_split(x, y, 0.2)

# %% [markdown]
# ### 引入梯度下降和正规方程法的线性模型

# %%
G_lr = GradientDescent.LinearRegression(alpha=0.00000001, cycle=10000)
N_lr = NormalEquation.LinearRegression(normalization=True)

# %% [markdown]
# ### 训练拟合

# %%
G_lr.fit(x_train, y_train)
N_lr.fit(x_train, y_train)
G = G_lr.predict(x_test)
N = N_lr.predict(x_test)

# %%
# 正规方程模型十次交叉验证, rSquare评价
cross_validation(x, y, N_lr, rSquare)
# Out:
# 0.6252623155961119

# %%
# 模型评估
N1 = rSquare(y_test, N)
N2 = MAE(y_test, N)
N3 = MSE(y_test, N)
N4 = RMSE(y_test, N)
N5 = MAPE(y_test, N)
G1 = rSquare(y_test, G)
G2 = MAE(y_test, G)
G3 = MSE(y_test, G)
G4 = RMSE(y_test, G)
G5 = MAPE(y_test, G)
print('梯度下降：', 'r2:', G1, 'MAE:', G2, 'MSE:', G3, 'RMSE:', G4, 'MAPE:', G5)
print('正规方程：', 'r2:', N1, 'MAE:', N2, 'MSE:', N3, 'RMSE:', N4, 'MAPE:', N5)
# Out:
# 梯度下降： r2: 0.5725086676388089 MAE: 25282.25150361814 MSE: 1208272999.7607262 RMSE: 34760.22151483972 MAPE: 0.15476436883562994
# 正规方程： r2: 0.7252931861894373 MAE: 18692.71152150586 MSE: 776438727.176712 RMSE: 27864.650135551892 MAPE: 0.11286302236295868

# %% [markdown]
# ## 对比sklearn

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error, mean_absolute_percentage_error

# %%
sk_lr = LinearRegression()
sk_lr.fit(x_train, y_train)
sk_res = sk_lr.predict(x_test)
sk1 = r2_score(y_test, sk_res)
sk2 = mean_absolute_error(y_test, sk_res)
sk3 = mean_squared_error(y_test, sk_res)
sk4 = np.sqrt(mean_squared_error(y_test, sk_res))
sk5 = mean_absolute_percentage_error(y_test, sk_res)
print('sklearn：', 'r2:', sk1, 'MAE:', sk2, 'MSE:', sk3, 'RMSE:', sk4, 'MAPE:', sk5)
# Out:
# sklearn： r2: 0.7252367135544899 MAE: 18700.636072321802 MSE: 776598342.9510376 RMSE: 27867.514115023565 MAPE: 0.11293158485008997

# %% [markdown]
# ### 可以看出正规方程法和sklearn的模型各个评分基本一致， 但梯度下降就差很多，明显没有达到最优

# %% [markdown]
# ## 数据归一化处理

# %%
x_tr = pp.MinMaxScale(x_train)
x_te = pp.MinMaxScale(x_test, keep=True)
x_len = pp.len
x_min = pp.min
y_tr = pp.MinMaxScale(y_train)
y_te = pp.MinMaxScale(y_test, keep=True)
y_len = pp.len
y_min = pp.min

# %%
G_lr_new = GradientDescent.LinearRegression(alpha=0.075, cycle=10000)

# %% [markdown]
# ### 数据拟合

# %%
G_lr_new.fit(x_tr, y_tr)
G_new = G_lr_new.predict(x_te)

# %%
# 归一化模型评分
G_new = G_new * y_len[0] + y_min[0]
s1 = rSquare(y_test, G_new)
s2 = MAE(y_test, G_new)
s3 = MSE(y_test, G_new)
s4 = RMSE(y_test, G_new)
s5 = MAPE(y_test, G_new)
print('梯度下降(归一化)：', 'r2:', s1, 'MAE:', s2, 'MSE:', s3, 'RMSE:', s4, 'MAPE:', s5)
# Out:
# 梯度下降(归一化)： r2: 0.7216837692395444 MAE: 18763.204927789608 MSE: 786640480.3241878 RMSE: 28047.111800044364 MAPE: 0.11344773439254793

# %% [markdown]
# ## 可以发现梯度下降和正规方程的最优解基本评分一致

# %% [markdown]
# ## 对test数据进行预测

# %% [markdown]
# ### 数据引入，选择特征

# %%
test = pd.read_csv('Data/house-prices-advanced-regression-techniques/test.csv')
test = test[data.iloc[:, :-1].columns]
test.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0          20       RH         80.0    11622   Pave      Reg         Lvl
# 1          20       RL         81.0    14267   Pave      IR1         Lvl
# 2          60       RL         74.0    13830   Pave      IR1         Lvl
# 3          60       RL         78.0     9978   Pave      IR1         Lvl
# 4         120       RL         43.0     5005   Pave      IR1         HLS
#
#   Utilities LotConfig LandSlope  ... GarageArea GarageQual GarageCond  \
# 0    AllPub    Inside       Gtl  ...      730.0         TA         TA
# 1    AllPub    Corner       Gtl  ...      312.0         TA         TA
# 2    AllPub    Inside       Gtl  ...      482.0         TA         TA
# 3    AllPub    Inside       Gtl  ...      470.0         TA         TA
# 4    AllPub    Inside       Gtl  ...      506.0         TA         TA
#
#   PavedDrive WoodDeckSF  OpenPorchSF  MoSold  YrSold  SaleType SaleCondition
# ...

# %%
# 缺失值判断
test.isnull().sum()
# Out:
# MSSubClass         0
# MSZoning           4
# LotFrontage      227
# LotArea            0
# Street             0
#                 ...
# OpenPorchSF        0
# MoSold             0
# YrSold             0
# SaleType           1
# SaleCondition      0
# Length: 66, dtype: int64

# %%
# 缺失值填充
test = pp.FillNan(test, limit=80, method='fb')

# %%
# 再次检查是否有遗漏的缺失值
test.isnull().sum().sum()
# Out:
# 0

# %%
# 标签编码
obj = (test.dtypes == object)[(test.dtypes == object) == True].index
test[obj] = pp.LabelEncode(test[obj])

# %%
# 特征选择并查看数据
test = test[c.index[:-1]]
test.head()
# Out:
#    MSSubClass  LotFrontage  LotArea  LotShape  Neighborhood  BldgType  \
# 0          20         80.0    11622         0            11         4
# 1          20         81.0    14267         1            11         4
# 2          60         74.0    13830         1            15         4
# 3          60         78.0     9978         1            15         4
# 4         120         43.0     5005         1            16         2
#
#    OverallQual  OverallCond  YearBuilt  YearRemodAdd  ...  GarageYrBlt  \
# 0            5            6       1961          1961  ...       1961.0
# 1            6            6       1958          1958  ...       1958.0
# 2            5            5       1997          1998  ...       1997.0
# 3            6            6       1998          1998  ...       1998.0
# 4            8            5       1992          1992  ...       1992.0
#
#    GarageFinish  GarageCars  GarageArea  GarageQual  GarageCond  PavedDrive  \
# ...

# %% [markdown]
# ### 用训练好的模型进行预测

# %%
gradient_predict = G_lr_new.predict((test - x_min) / x_len) * y_len[0] + y_min[0]
normal_predict = N_lr.predict(test)

# %% [markdown]
# ## 双模型联合预测

# %%
pred = (gradient_predict + normal_predict) / 2
pred
# Out:
# array([[130904.62667192],
#        [157771.2354178 ],
#        [186564.52132667],
#        ...,
#        [181323.7844744 ],
#        [128120.77163944],
#        [198880.09869974]])
