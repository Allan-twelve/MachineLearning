# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from DataSet_tools.data_processing import PreProcessing
# %matplotlib inline

# %%
customers = pd.read_csv('Data/Brazilian E-Commerce Public Dataset by Olist/olist_customers_dataset.csv')
geolocation = pd.read_csv('Data/Brazilian E-Commerce Public Dataset by Olist/olist_geolocation_dataset.csv')
items = pd.read_csv('Data/Brazilian E-Commerce Public Dataset by Olist/olist_order_items_dataset.csv')
payments = pd.read_csv('Data/Brazilian E-Commerce Public Dataset by Olist/olist_order_payments_dataset.csv')
reviews = pd.read_csv('Data/Brazilian E-Commerce Public Dataset by Olist/olist_order_reviews_dataset.csv')
orders = pd.read_csv('Data/Brazilian E-Commerce Public Dataset by Olist/olist_orders_dataset.csv')
products = pd.read_csv('Data/Brazilian E-Commerce Public Dataset by Olist/olist_products_dataset.csv')
sellers = pd.read_csv('Data/Brazilian E-Commerce Public Dataset by Olist/olist_sellers_dataset.csv')
category = pd.read_csv('Data/Brazilian E-Commerce Public Dataset by Olist/product_category_name_translation.csv')

# %%
cust = customers.copy()
customers.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %%
cust = cust.set_index(['customer_state', 'customer_city', 'customer_zip_code_prefix'])
cust = cust.sort_index()
cust
# Out:
#                                                                               customer_id  \
# customer_state customer_city   customer_zip_code_prefix
# AC             brasileia       69932                     b1161707c5b3711b7cf6213c114c91b2
#                cruzeiro do sul 69980                     757bbd8c61a5fd67d5b8c18efd987beb
#                                69980                     f23c4b530f6d7d421de1e38d3e0cc327
#                                69980                     ee0ab5a9747a11f916fff4b4fc306ac0
#                epitaciolandia  69934                     8a45f7d2b87f16a273fd86e9d5efc35a
# ...                                                                                   ...
# TO             tocantinopolis  77900                     47f773dfff4d38e72ce3d45027b55ca4
#                                77900                     57d7a0e97246823d94b31681180a91a1
#                xambioa         77880                     83486328de12e85d29b27790fd68f911
# ...

# %%
geo = geolocation.copy()
geo.head()
# Out:
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                         1037       -23.545621       -46.639292
# 1                         1046       -23.546081       -46.644820
# 2                         1046       -23.546129       -46.642951
# 3                         1041       -23.544392       -46.639499
# 4                         1035       -23.541578       -46.641607
#
#   geolocation_city geolocation_state
# 0        sao paulo                SP
# 1        sao paulo                SP
# 2        sao paulo                SP
# 3        sao paulo                SP
# 4        sao paulo                SP

# %%
geo = geo.set_index(['geolocation_state', 'geolocation_city', 'geolocation_zip_code_prefix'])
geo = geo.sort_index()
geo
# Out:
#                                                                 geolocation_lat  \
# geolocation_state geolocation_city geolocation_zip_code_prefix
# AC                acrelandia       69945                             -10.074669
#                                    69945                             -10.080001
#                                    69945                              -9.937884
#                                    69945                             -10.077416
#                                    69945                             -10.077757
# ...                                                                         ...
# TO                xambioá          77880                              -6.412219
#                                    77880                              -6.413853
#                                    77880                              -6.407600
#                                    77880                              -6.417654
# ...

# %%
geo.name
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-3b508bbb7296> in <module>
# ----> 1 geo.name
#
# D:\anaconda\envs\learn\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'name'
